# %% [markdown]
# # Multi-Object Tracking

# %% [markdown]
# ## Importing libraries

# %%
# !nvidia-smi
# Out:
# Sat Feb 15 15:37:08 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 572.16                 Driver Version: 572.16         CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3070 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   50C    P0             26W /  105W |    1014MiB /   8192MiB |      2%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Coding\MOT-yolo11

# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.55  Python-3.11.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# Setup complete  (16 CPUs, 15.2 GB RAM, 750.9/802.3 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %pip install pickleshare
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install --upgrade opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---- ----------------------------------- 4.7/39.5 MB 23.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.0/39.5 MB 27.5 MB/s eta 0:00:02
#    ------------- -------------------------- 13.1/39.5 MB 23.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.8/39.5 MB 26.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.8/39.5 MB 27.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.8/39.5 MB 27.5 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.5 MB 27.4 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 25.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %% [markdown]
# ## Tracking

# %%
os.getcwd()
# Out:
# 'c:\\Coding\\MOT-yolo11'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model=YOLO("runs/detect/train1/weights/best.pt").to(device)

# %% [markdown]
# ### ByteTrack

# %%
# !yolo task=detect mode=track tracker=bytetrack.yaml model=runs/detect/train/weights/best.pt conf=0.45 source=testvideos/test1.mp4 save=True save_txt=True
# Out:
# Ultralytics 8.3.55 🚀 Python-3.11.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLO11l summary (fused): 464 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
#
# video 1/1 (frame 1/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 128.4ms
# video 1/1 (frame 2/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 31.1ms
# video 1/1 (frame 3/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 30.7ms
# video 1/1 (frame 4/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 28.4ms
# video 1/1 (frame 5/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 30.6ms
# video 1/1 (frame 6/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 34.1ms
# video 1/1 (frame 7/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 40.0ms
# video 1/1 (frame 8/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 32.8ms
# ...

# %%
# !yolo task=detect mode=track tracker=bytetrack.yaml model=runs/detect/train/weights/best.pt conf=0.45 source=testvideos/test2.mp4 save=True save_txt=True
# Out:
# Ultralytics 8.3.55 🚀 Python-3.11.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLO11l summary (fused): 464 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
#
# video 1/1 (frame 1/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 6 spiderss, 99.7ms
# video 1/1 (frame 2/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 32.7ms
# video 1/1 (frame 3/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 30.3ms
# video 1/1 (frame 4/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 31.0ms
# video 1/1 (frame 5/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 25.9ms
# video 1/1 (frame 6/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 6 spiderss, 35.8ms
# video 1/1 (frame 7/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 32.0ms
# video 1/1 (frame 8/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 36.8ms
# ...

# %%
# !yolo task=detect mode=track tracker=bytetrack.yaml model=runs/detect/train/weights/best.pt conf=0.45 source=testvideos/test3.mp4 save=True save_txt=True
# Out:
# Ultralytics 8.3.55 🚀 Python-3.11.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLO11l summary (fused): 464 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
#
# video 1/1 (frame 1/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 108.0ms
# video 1/1 (frame 2/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 34.3ms
# video 1/1 (frame 3/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 43.8ms
# video 1/1 (frame 4/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 32.9ms
# video 1/1 (frame 5/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 36.9ms
# video 1/1 (frame 6/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 34.1ms
# video 1/1 (frame 7/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 35.0ms
# video 1/1 (frame 8/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 30.2ms
# ...

# %%
# !yolo task=detect mode=track tracker=bytetrack.yaml model=runs/detect/train/weights/best.pt conf=0.45 source=testvideos/test4.mp4 save=True save_txt=True
# Out:
# Ultralytics 8.3.55 🚀 Python-3.11.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLO11l summary (fused): 464 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
#
# video 1/1 (frame 1/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 115.4ms
# video 1/1 (frame 2/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 9 spiderss, 33.5ms
# video 1/1 (frame 3/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 39.2ms
# video 1/1 (frame 4/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 40.3ms
# video 1/1 (frame 5/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 40.8ms
# video 1/1 (frame 6/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 30.1ms
# video 1/1 (frame 7/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 41.2ms
# video 1/1 (frame 8/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 30.7ms
# ...

# %% [markdown]
# ### BotSORT

# %%
# !yolo task=detect mode=track tracker=botsort.yaml model=runs/detect/train/weights/best.pt conf=0.45 source=testvideos/test1.mp4 save=True save_txt=True
# Out:
# Ultralytics 8.3.55 🚀 Python-3.11.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLO11l summary (fused): 464 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
#
# video 1/1 (frame 1/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 99.1ms
# video 1/1 (frame 2/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 32.7ms
# video 1/1 (frame 3/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 34.8ms
# video 1/1 (frame 4/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 35.4ms
# video 1/1 (frame 5/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 33.1ms
# video 1/1 (frame 6/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 34.7ms
# video 1/1 (frame 7/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 37.7ms
# video 1/1 (frame 8/682) c:\Coding\MOT-yolo11\testvideos\test1.mp4: 544x960 5 spiderss, 29.3ms
# ...

# %%
# !yolo task=detect mode=track tracker=botsort.yaml model=runs/detect/train/weights/best.pt conf=0.45 source=testvideos/test2.mp4 save=True save_txt=True
# Out:
# Ultralytics 8.3.55 🚀 Python-3.11.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLO11l summary (fused): 464 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
#
# video 1/1 (frame 1/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 6 spiderss, 98.1ms
# video 1/1 (frame 2/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 30.9ms
# video 1/1 (frame 3/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 34.0ms
# video 1/1 (frame 4/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 31.5ms
# video 1/1 (frame 5/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 42.2ms
# video 1/1 (frame 6/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 6 spiderss, 33.6ms
# video 1/1 (frame 7/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 23.1ms
# video 1/1 (frame 8/454) c:\Coding\MOT-yolo11\testvideos\test2.mp4: 544x960 5 spiderss, 30.3ms
# ...

# %%
# !yolo task=detect mode=track tracker=botsort.yaml model=runs/detect/train/weights/best.pt conf=0.45 source=testvideos/test3.mp4 save=True save_txt=True
# Out:
# Ultralytics 8.3.55 🚀 Python-3.11.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLO11l summary (fused): 464 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
#
# video 1/1 (frame 1/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 113.9ms
# video 1/1 (frame 2/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 45.6ms
# video 1/1 (frame 3/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 56.2ms
# video 1/1 (frame 4/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 29.7ms
# video 1/1 (frame 5/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 32.0ms
# video 1/1 (frame 6/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 35.3ms
# video 1/1 (frame 7/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 38.6ms
# video 1/1 (frame 8/352) c:\Coding\MOT-yolo11\testvideos\test3.mp4: 544x960 2 spiderss, 33.4ms
# ...

# %%
# !yolo task=detect mode=track tracker=botsort.yaml model=runs/detect/train/weights/best.pt conf=0.45 source=testvideos/test4.mp4 save=True save_txt=True
# Out:
# Ultralytics 8.3.55 🚀 Python-3.11.3 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLO11l summary (fused): 464 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
#
# video 1/1 (frame 1/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 106.0ms
# video 1/1 (frame 2/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 9 spiderss, 35.1ms
# video 1/1 (frame 3/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 37.0ms
# video 1/1 (frame 4/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 29.6ms
# video 1/1 (frame 5/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 31.0ms
# video 1/1 (frame 6/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 29.9ms
# video 1/1 (frame 7/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 35.0ms
# video 1/1 (frame 8/508) c:\Coding\MOT-yolo11\testvideos\test4.mp4: 544x960 10 spiderss, 34.8ms
# ...
